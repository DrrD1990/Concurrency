# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mathtext as mathtext
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

mathtext.FontConstantsBase.sup1 = 0.25
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "Arial"
plt.rcParams['mathtext.fontset'] = "custom"
plt.rcParams["mathtext.rm"] = "Arial"
plt.rcParams['mathtext.it'] = 'Arial:italic'

rows, cols = 3, 4
fig, ax = plt.subplots(rows, cols, sharey = 'row', figsize=(16,10))

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('erM1dp_q0.1_s_a2.txt')
fraction_recovered_1_3 = np.loadtxt('erM1dp_q0.1_s_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, fraction_recovered_1_2,
                                       fraction_recovered_1_3), axis=0)
fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('erM3_q0.1_s_a2.txt')
fraction_recovered_3_3 = np.loadtxt('erM3_q0.1_s_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)
beta_list1 = [0, 0.5, 1.0, 1.3]
beta_list2 = list(np.arange(1.4, 2.3, 0.25))
beta_list3 = list(np.arange(2.3, 10.01, 0.25))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 0.5, 1.0, 1.64]
beta_list5 = list(np.arange(1.65, 2.3, 0.25))
beta_list6 = list(np.arange(2.3, 10.01, 0.25))
beta_list7 = np.concatenate((beta_list4, beta_list5, beta_list6), axis=0)


#ax[0,0].set_title('ER, $q^*=0.1$, slow', fontsize=14)
ax[0,0].tick_params(labelsize=15)
ax[0,0].set_xlim([0.0, 9.8])
ax[0,0].set_xticks([0, 2, 4, 6, 8])
ax[0,0].set_xticklabels(['0','2','4','6','8'])
ax[0,0].set_ylim([0.0, 1.0])
ax[0,0].set_yticks([0, 0.5, 1])
ax[0,0].set_yticklabels(['0', '0.5', '1'])
ax[0,0].plot(beta_list7, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[0,0].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
#legend_font = {'family' : 'Arial', 'weight' : 'normal', 'size': 12}
#ax[0,0].legend(prop=legend_font)
ax[0,0].legend(fontsize=12)
fig.text(0.1, 0.9, '(a)', fontsize=16)
fig.text(0.15, 0.9, 'ER, $q^*=0.1$, slow', fontsize=15)

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('erM1dp_q0.1_f_a.txt')
fraction_recovered_1_3 = np.loadtxt('erM1dp_q0.1_f_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, fraction_recovered_1_2,
                                       fraction_recovered_1_3), axis=0)
fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('erM3_q0.1_f_a.txt')
fraction_recovered_3_3 = np.loadtxt('erM3_q0.1_f_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)
beta_list1 = [0, 0.5, 1.0, 1.3]
beta_list2 = list(np.arange(1.31, 1.4, 0.04))
beta_list3 = list(np.arange(1.4, 10.01, 0.25))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 1.0, 1.5, 1.7]
beta_list5 = list(np.arange(1.71, 1.8, 0.04))
beta_list6 = list(np.arange(1.8, 10.01, 0.25))
beta_list7 = np.concatenate((beta_list4, beta_list5, beta_list6), axis=0)

#ax[0,1].set_title('ER, $q^*=0.1$, fast', fontsize=14)
ax[0,1].tick_params(labelsize=15)
ax[0,1].set_xlim([0.0, 9.8])
ax[0,1].set_ylim([0.0, 1.0])
ax[0,1].set_xticks([0, 2, 4, 6, 8])
ax[0,1].set_xticklabels(['0', '2', '4', '6', '8'])
ax[0,1].plot(beta_list7, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[0,1].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.31, 0.9, '(b)', fontsize=16)
fig.text(0.355, 0.9, 'ER, $q^*=0.1$, fast', fontsize=15)

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('erM1dp_q0.5_s_a.txt')
fraction_recovered_1_3 = np.loadtxt('erM1dp_q0.5_s_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, fraction_recovered_1_2,
                                       fraction_recovered_1_3), axis=0)

fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('erM3_q0.5_s_a.txt')
fraction_recovered_3_3 = np.loadtxt('erM3_q0.5_s_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)


beta_list1 = [0, 0.1, 0.2, 0.25]
beta_list2 = list(np.arange(0.26, 0.3, 0.01))
beta_list3 = list(np.arange(0.3, 2.83, 0.07))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 0.1, 0.2, 0.3]
beta_list5 = list(np.arange(0.318, 0.3191, 0.001))
beta_list6 = list(np.arange(0.32, 2.83, 0.07))
beta_list7 = np.concatenate((beta_list4, beta_list5, beta_list6), axis=0)

#ax[0,2].set_title('ER, $q^*=0.5$, slow', fontsize=14)
ax[0,2].tick_params(labelsize=15)
ax[0,2].set_xlim([0.0, 2.75])
ax[0,2].set_xticklabels(['0', '1', '2'])
ax[0,2].set_ylim([0.0, 1.0])
ax[0,2].plot(beta_list7, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[0,2].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.513, 0.9, '(c)', fontsize=16)
fig.text(0.559, 0.9, 'ER, $q^*=0.5$, slow', fontsize=15)

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('erM1dp_q0.5_f_a.txt')
fraction_recovered_1_3 = np.loadtxt('erM1dp_q0.5_f_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, fraction_recovered_1_2,
                                       fraction_recovered_1_3), axis=0)
fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('erM3_q0.5_f_a.txt')
fraction_recovered_3_3 = np.loadtxt('erM3_q0.5_f_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)

beta_list1 = [0, 0.1, 0.2, 0.25]
beta_list2 = list(np.arange(0.26, 0.3, 0.01))
beta_list3 = list(np.arange(0.3, 2.83, 0.07))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 0.1, 0.2, 0.3]
beta_list5 = list(np.arange(0.318, 0.3191, 0.001))
beta_list6 = list(np.arange(0.32, 2.83, 0.07))
beta_list7 = np.concatenate((beta_list4, beta_list5, beta_list6), axis=0)

#ax[0,3].set_title('ER, $q^*=0.5$, fast', fontsize=14)
ax[0,3].tick_params(labelsize=15)
ax[0,3].set_xlim([0.0, 2.75])
ax[0,3].set_xticklabels(['0', '1', '2'])
ax[0,3].set_ylim([0.0, 1.0])
ax[0,3].plot(beta_list7, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[0,3].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.714, 0.9, '(d)', fontsize=16)
fig.text(0.76, 0.9, 'ER, $q^*=0.5$, fast', fontsize=15)


fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('baM1dp_q0.1_s_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, 
                                       fraction_recovered_1_2), axis=0)

fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('baM3_q0.1_s_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1,
                                       fraction_recovered_3_2), axis=0)

beta_list1 = [0, 0.5, 1.0, 1.43]
beta_list2 = list(np.arange(1.6, 10.01, 0.25))
beta_list = np.concatenate((beta_list1, beta_list2), axis=0)

beta_list3 = [0, 0.5, 1.0, 1.6]
beta_list4 = list(np.arange(1.85, 10.01, 0.25))
beta_list5 = np.concatenate((beta_list3, beta_list4), axis=0)


#ax[1,0].set_title('BA, $q^*=0.1$, slow', fontsize=14)
ax[1,0].tick_params(labelsize=15)
ax[1,0].set_xlim([0.0, 9.8])
ax[1,0].set_xticks([0, 2, 4, 6, 8])
ax[1,0].set_xticklabels(['0','2','4','6','8'])
ax[1,0].set_ylim([0.0, 1.0])
ax[1,0].set_yticks([0, 0.5, 1])
ax[1,0].set_yticklabels(['0', '0.5', '1'])
ax[1,0].plot(beta_list5, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[1,0].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.1, 0.615, '(e)', fontsize=16)
fig.text(0.15, 0.615, 'BA, $q^*=0.1$, slow', fontsize=15)

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('baM1dp_q0.1_f_a.txt')
fraction_recovered_1_3 = np.loadtxt('baM1dp_q0.1_f_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, fraction_recovered_1_2,
                                       fraction_recovered_1_3), axis=0)
fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('baM3_q0.1_f_a.txt')
fraction_recovered_3_3 = np.loadtxt('baM3_q0.1_f_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)
beta_list1 = [0, 0.5, 1.0, 1.3]
beta_list2 = list(np.arange(1.35, 1.54, 0.1))
beta_list3 = list(np.arange(1.6, 10.01, 0.25))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 0.5, 1.0, 1.5]
beta_list5 = list(np.arange(1.53, 1.6, 0.05))
beta_list6 = list(np.arange(1.85, 10.01, 0.25))
beta_list7 = np.concatenate((beta_list4, beta_list5, beta_list6), axis=0)

#ax[1,1].set_title('BA, $q^*=0.1$, fast', fontsize=14)
ax[1,1].tick_params(labelsize=15)
ax[1,1].set_xlim([0.0, 9.8])
ax[1,1].set_ylim([0.0, 1.0])
ax[1,1].set_xticks([0, 2, 4, 6, 8])
ax[1,1].set_xticklabels(['0', '2', '4', '6', '8'])
ax[1,1].plot(beta_list7, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[1,1].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.31, 0.615, '(f)', fontsize=16)
fig.text(0.355, 0.615, 'BA, $q^*=0.1$, fast', fontsize=15)

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('baM1dp_q0.5_s_a.txt')
fraction_recovered_1_3 = np.loadtxt('baM1dp_q0.5_s_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, fraction_recovered_1_2,
                                       fraction_recovered_1_3), axis=0)
fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('baM3_q0.5_s_a.txt')
fraction_recovered_3_3 = np.loadtxt('baM3_q0.5_s_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)
beta_list1 = [0, 0.06, 0.12, 0.2]
beta_list2 = list(np.arange(0.22, 0.3, 0.03))
beta_list3 = list(np.arange(0.3, 2.83, 0.07))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 0.1, 0.2, 0.25]
beta_list5 = list(np.arange(0.26, 0.3, 0.02))
beta_list6 = list(np.arange(0.3, 2.83, 0.07))
beta_list7 = np.concatenate((beta_list4, beta_list5, beta_list6), axis=0)

#ax[1,2].set_title('BA, $q^*=0.5$, slow', fontsize=14)
ax[1,2].tick_params(labelsize=15)
ax[1,2].set_xlim([0.0, 2.8])
ax[1,2].set_xticklabels(['0', '1', '2'])
ax[1,2].set_ylim([0.0, 1.0])
ax[1,2].plot(beta_list7, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[1,2].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.513, 0.615, '(g)', fontsize=16)
fig.text(0.559, 0.615, 'BA, $q^*=0.5$, slow', fontsize=15)

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('baM1dp_q0.5_f_a.txt')
fraction_recovered_1_3 = np.loadtxt('baM1dp_q0.5_f_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, fraction_recovered_1_2,
                                       fraction_recovered_1_3), axis=0)
fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('baM3_q0.5_f_a.txt')
fraction_recovered_3_3 = np.loadtxt('baM3_q0.5_f_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)

beta_list1 = [0, 0.06, 0.12, 0.2]
beta_list2 = list(np.arange(0.22, 0.3, 0.03))
beta_list3 = list(np.arange(0.3, 2.81, 0.07))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 0.1, 0.2, 0.25]
beta_list5 = list(np.arange(0.26, 0.3, 0.02))
beta_list6 = list(np.arange(0.3, 2.81, 0.07))
beta_list7 = np.concatenate((beta_list4, beta_list5, beta_list6), axis=0)


#ax[1,3].set_title('BA, $q^*=0.5$, fast', fontsize=14)
ax[1,3].tick_params(labelsize=15)
ax[1,3].set_xlim([0.0, 2.75])
ax[1,3].set_xticklabels(['0', '1', '2'])
ax[1,3].set_ylim([0.0, 1.0])
ax[1,3].plot(beta_list7, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[1,3].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.714, 0.615, '(h)', fontsize=16)
fig.text(0.76, 0.615, 'BA, $q^*=0.5$, fast', fontsize=15)

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('emM1dp_q0.1_s_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, 
                                       fraction_recovered_1_2), axis=0)

fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('emM3_q0.1_s_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1,
                                       fraction_recovered_3_2), axis=0)
beta_list1 = [0, 1.5, 3.0, 3.7]
beta_list2 = list(np.arange(5.0, 40.01, 1.0))
beta_list = np.concatenate((beta_list1, beta_list2), axis=0)

beta_list3 = [0, 1.5, 3.0, 4.7]
beta_list4 = list(np.arange(6.0, 40.01, 1.0))
beta_list5 = np.concatenate((beta_list3, beta_list4), axis=0)

#ax[2,0].set_title('Collabo., $q^*=0.1$, slow', fontsize=14)
ax[2,0].tick_params(labelsize=15)
ax[2,0].set_xlim([0.0, 40])
ax[2,0].set_xticklabels(['0', '10', '20', '30', '40'])
ax[2,0].set_ylim([0.0, 1.0])
ax[2,0].set_yticks([0, 0.5, 1])
ax[2,0].set_yticklabels(['0', '0.5', '1'])
ax[2,0].plot(beta_list5, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[2,0].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.1, 0.33, '(i)', fontsize=16)
fig.text(0.13, 0.33, 'Collabo., $q^*=0.1$, slow', fontsize=15)

#inset_axes = inset_axes(ax[2,0], width="50%", height=0.8, loc=1)
#inset_axes = fig.add_axes([0.2, 0.21, 0.08, 0.08])
#inset_axes.set_xlim([0.0, 40])
#inset_axes.set_xticks([0, 10, 20, 30, 40])
#inset_axes.set_xticklabels(['0', '10', '20', '30', '40'])
#inset_axes.set_ylim([0.0, 0.04])
#inset_axes.set_yticks([0, 0.02, 0.04])
#inset_axes.set_yticklabels(['0', '0.02', '0.04'])
#inset_axes.set_xlabel('Infection rate', fontsize=12)
#inset_axes.plot(beta_list, fraction_recovered_1prime, linewidth=1.5, label="Model 1'")
#inset_axes.plot(beta_list, fraction_recovered_2, linewidth=1.5, label='Model 2')

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('emM1dp_q0.1_f_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, 
                                       fraction_recovered_1_2), axis=0)
fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('emM3_q0.1_f_a.txt')
fraction_recovered_3_3 = np.loadtxt('emM3_q0.1_f_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)
beta_list1 = [0, 1.5, 3.0, 3.7]
beta_list2 = list(np.arange(3.8, 4.9, 0.4))
beta_list3 = list(np.arange(5.0, 40.01, 1.0))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 1.5, 3.0, 5.0]
beta_list5 = list(np.arange(6.0, 40.01, 1.0))
beta_list6 = np.concatenate((beta_list4, beta_list5), axis=0)

#ax[2,1].set_title('Collabo., $q^*=0.1$, fast', fontsize=14)
ax[2,1].tick_params(labelsize=15)
ax[2,1].set_xlim([0.0, 40])
ax[2,1].set_xticklabels(['0', '10', '20', '30', '40'])
ax[2,1].set_ylim([0.0, 1.0])
ax[2,1].plot(beta_list6, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[2,1].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.31, 0.33, '(j)', fontsize=16)
fig.text(0.34, 0.33, 'Collabo., $q^*=0.1$, fast', fontsize=15)

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('emM1dp_q0.5_s_a.txt')
fraction_recovered_1_3 = np.loadtxt('emM1dp_q0.5_s_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1, fraction_recovered_1_2,
                                       fraction_recovered_1_3), axis=0)
fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('emM3_q0.5_s_a.txt')
fraction_recovered_3_3 = np.loadtxt('emM3_q0.5_s_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)

beta_list1 = [0, 0.15, 0.3, 0.45]
beta_list2 = list(np.arange(0.51, 0.6, 0.05))
beta_list3 = list(np.arange(0.6, 6.01, 0.15))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 0.2, 0.4, 0.55]
beta_list5 = list(np.arange(0.58, 0.65, 0.05))
beta_list6 = list(np.arange(0.65, 6.01, 0.15))
beta_list7 = np.concatenate((beta_list4, beta_list5, beta_list6), axis=0)

#ax[2,2].set_title('Collabo., $q^*=0.5$, slow', fontsize=14)
ax[2,2].tick_params(labelsize=15)
ax[2,2].set_xlim([0.0, 5.9])
ax[2,2].set_xticklabels(['0', '2', '4', '6'])
ax[2,2].set_ylim([0.0, 1.0])
ax[2,2].plot(beta_list7, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[2,2].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.51, 0.33, '(k)', fontsize=16)
fig.text(0.54, 0.33, 'Collabo., $q^*=0.5$, slow', fontsize=15)

fraction_recovered_1_1 = [0, 0, 0, 0]
fraction_recovered_1_2 = np.loadtxt('emM1dp_q0.5_f_b.txt')
fraction_recovered_1 = np.concatenate((fraction_recovered_1_1,
                                       fraction_recovered_1_2), axis=0)
fraction_recovered_3_1 = [0, 0, 0, 0]
fraction_recovered_3_2 = np.loadtxt('emM3_q0.5_f_a.txt')
fraction_recovered_3_3 = np.loadtxt('emM3_q0.5_f_b.txt')
fraction_recovered_3 = np.concatenate((fraction_recovered_3_1, fraction_recovered_3_2,
                                       fraction_recovered_3_3), axis=0)
beta_list1 = [0, 0.15, 0.3, 0.45]
beta_list2 = list(np.arange(0.46, 0.6, 0.05))
beta_list3 = list(np.arange(0.6, 6.01, 0.15))
beta_list = np.concatenate((beta_list1, beta_list2, beta_list3), axis=0)

beta_list4 = [0, 0.2, 0.4, 0.55]
beta_list5 = list(np.arange(0.6, 6.01, 0.15))
beta_list6 = np.concatenate((beta_list4, beta_list5), axis=0)

#ax[2,3].set_title('Collabo., $q^*=0.5$, fast', fontsize=14)
ax[2,3].tick_params(labelsize=15)
ax[2,3].set_xlim([0.0, 5.9])
ax[2,3].set_xticklabels(['0', '2', '4', '6'])
ax[2,3].set_ylim([0.0, 1.0])
ax[2,3].plot(beta_list6, fraction_recovered_1, linewidth=1.5, label='Model 1"')
ax[2,3].plot(beta_list, fraction_recovered_3, linewidth=1.5, label='Model 3')
fig.text(0.714, 0.33, '(l)', fontsize=16)
fig.text(0.744, 0.33, 'Collabo., $q^*=0.5$, fast', fontsize=15)

fig.text(0.5, 0.04, 'Infection rate', ha='center', va='center', fontsize=28)
fig.text(0.06, 0.5, 'Fraction of infectious nodes', ha='center', va='center', rotation='vertical', fontsize=28)
plt.subplots_adjust(hspace=0.5)
#plt.tight_layout()
plt.savefig('sis_1dp_vs_3.pdf', bbox_inches="tight")
plt.show()
